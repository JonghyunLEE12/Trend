# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
import time
import re

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.get('https://watcha.com/staffmades/409')

# %%
for _ in range(30) :
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(0.5)

# %%
doms = driver.find_elements_by_css_selector('div.css-bh4lon')
print("프로그램 총갯수 :", len(doms))
# Out:
# 프로그램 총갯수 : 301

# %%
urllist = []
for dd in doms :
    driver.execute_script("arguments[0].dispatchEvent(new MouseEvent('mouseover', { 'view': window, 'bubbles': true, 'cancelable': true }))", dd)
    time.sleep(1)
    tt=driver.find_element_by_css_selector('#root .overlay-transition-enter-done > a')
    urlstr = tt.get_attribute('href')
    print(urlstr)
    urllist.append(urlstr)
    driver.execute_script("arguments[0].dispatchEvent(new MouseEvent('mouseout', { 'view': window, 'bubbles': true, 'cancelable': true }))", dd)
# Out:
# https://watcha.com/watch/tPDOmjL
# https://watcha.com/watch/tlObjnj
# https://watcha.com/watch/mdEmAbg
# https://watcha.com/watch/mdRLbZr
# https://watcha.com/watch/mYdEMpd
# https://watcha.com/watch/mWpkjx5
# https://watcha.com/watch/m5x42l5
# https://watcha.com/watch/mWpGwK5
# https://watcha.com/watch/tlGNyvD
# https://watcha.com/watch/tRB0Xql
# https://watcha.com/watch/tEZAY0d
# https://watcha.com/watch/tlLrynK
# https://watcha.com/watch/tPj1mQx
# https://watcha.com/watch/tRa3pLl
# https://watcha.com/watch/tRamnQR
# https://watcha.com/watch/tlGmjZR
# https://watcha.com/watch/tRNAaJE
# https://watcha.com/watch/tPeWOeD
# https://watcha.com/watch/tPDO9k1
# https://watcha.com/watch/tRp4byx
# https://watcha.com/watch/tRW0a6P
# https://watcha.com/watch/tR2ewJW
# https://watcha.com/watch/mmOb3kd
# https://watcha.com/watch/mMO2mNW
# https://watcha.com/watch/mWqJBpO
# https://watcha.com/watch/mM5rmEd
# https://watcha.com/watch/md6Y82O
# https://watcha.com/watch/m5xJqxO
# ...

# %%
print(urllist)
# Out:
# ['https://watcha.com/watch/tPDOmjL', 'https://watcha.com/watch/tlObjnj', 'https://watcha.com/watch/mdEmAbg', 'https://watcha.com/watch/mdRLbZr', 'https://watcha.com/watch/mYdEMpd', 'https://watcha.com/watch/mWpkjx5', 'https://watcha.com/watch/m5x42l5', 'https://watcha.com/watch/mWpGwK5', 'https://watcha.com/watch/tlGNyvD', 'https://watcha.com/watch/tRB0Xql', 'https://watcha.com/watch/tEZAY0d', 'https://watcha.com/watch/tlLrynK', 'https://watcha.com/watch/tPj1mQx', 'https://watcha.com/watch/tRa3pLl', 'https://watcha.com/watch/tRamnQR', 'https://watcha.com/watch/tlGmjZR', 'https://watcha.com/watch/tRNAaJE', 'https://watcha.com/watch/tPeWOeD', 'https://watcha.com/watch/tPDO9k1', 'https://watcha.com/watch/tRp4byx', 'https://watcha.com/watch/tRW0a6P', 'https://watcha.com/watch/tR2ewJW', 'https://watcha.com/watch/mmOb3kd', 'https://watcha.com/watch/mMO2mNW', 'https://watcha.com/watch/mWqJBpO', 'https://watcha.com/watch/mM5rmEd', 'https://watcha.com/watch/md6Y82O', 'https://watcha.com/watch
# ...

# %%
print(len(urllist))
# Out:
# 301

# %% [markdown]
# ## 설명을 위한 부분

# %%
doms = driver.find_elements_by_css_selector('div.css-bh4lon')
print("프로그램 총갯수 :", len(doms))
# Out:
# 프로그램 총갯수 : 18

# %%
# 과정설명 ㅎㅎ
driver.execute_script("arguments[0].dispatchEvent(new MouseEvent('mouseover', { 'view': window, 'bubbles': true, 'cancelable': true }))", doms[0])

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
import time
import re


genre_detailList=[]

driver = webdriver.Chrome('C:/Temp/chromedriver')

for i in range(len(urllist)):
    driver.get(str(urllist[i]))
    genre_detail=driver.find_elements_by_css_selector('#root > div.css-k25b4j-NavManager > main > div.css-w1vcuu > section > article.css-73pqgl > div.css-hiy713 > div > div.css-1k3zyqj > span:nth-child(5)')
    
    for dom in genre_detail:
        genre_detailList.append(dom.text)
        time.sleep(0.5)
    
         
        
    time.sleep(0.5)
    
    with open('output/왓챠추천_세부장르.csv', "wt", encoding="utf-8") as f:
        f.write('왓챠추천세부장르\n')  
        for i in range(len(genre_detailList)):
            f.write(genre_detailList[i]+'\n')
    
    
    
    
   
    
    
    
    
    time.sleep(0.5)

# %%
genre_detailList1=[]

driver = webdriver.Chrome('C:/Temp/chromedriver')

for i in range(len(urllist)):
    driver.get(str(urllist[i]))
    genre_detail=driver.find_elements_by_css_selector('#root > div.css-k25b4j-NavManager > main > div.css-w1vcuu > section > article.css-73pqgl > div.css-hiy713 > div > div.css-1k3zyqj')

    #if genre_detail == None:
        #genre_detailList1.append(None)
    #else:
    for dom in genre_detail:
        
        genre_detailList1.append(dom.text)
        time.sleep(0.5)
    
    
with open('output/왓차추천_세부장르.csv', "wt", encoding="utf-8") as f:
    f.write('왓차추천세부장르\n')  
    for i in range(len(genre_detailList1)):
        f.write(genre_detailList1[i]+'\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6120/2491217103.py in <module>
#       1 genre_detailList1=[]
#       2
# ----> 3 driver = webdriver.Chrome('C:/Temp/chromedriver')
#       4
#       5 for i in range(len(urllist)):
#
# NameError: name 'webdriver' is not defined

# %%
list1=[]
list1.append(None)
print(list1)
# Out:
# [None]

# %%
print(len(genreList))
print(len(genre_detailList))
# Out:
# 301
# 274

# %%
genreList1=[]
for i in range(0,len(genreList)+1):
    a=genreList[i]
    aa=a.replace(",","")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17980/703810712.py in <module>
#       1 genreList1=[]
#       2 for i in range(0,len(genreList)+1):
# ----> 3     a=genreList[i]
#       4     aa=a.replace(",","")
#       5
#
# IndexError: list index out of range

# %%
print(len(genreList))
print(len(genre_detailList))


with open('output/왓챠추천장르.csv', "wt", encoding="utf-8") as f:
    f.write('왓챠추천장르\n')  
    for i in range(len(genreList)):
        f.write(genreList[i]+'\n')
# Out:
# 301
# 274

# %%
print(len(genreList))
print(len(genre_detailList))
# Out:
# 301
# 274

# %%
with open('output/왓챠추천_장르.csv', "wt", encoding="utf-8") as f:
    f.write('왓챠추천장르,왓챠추천세부장르\n')  
    for i in range(len(genreList)):
        f.write(genreList[i]+','+genre_detailList[i]+'\n')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17980/3777023458.py in <module>
#       2     f.write('왓챠추천장르,왓챠추천세부장르\n')
#       3     for i in range(len(genreList)):
# ----> 4         f.write(genreList[i]+','+genre_detailList[i]+'\n')
#
# IndexError: list index out of range

# %%
import pandas as pd
watcha = pd.read_csv('./output/왓차_추천.csv',error_bad_lines=False)
display(watcha)

watcha_genre = pd.read_csv('./output/왓챠추천장르.csv',error_bad_lines=False)
display(watcha_genre)

watcha_list=pd.concat([watcha,watcha_genre] , axis=1)
display(watcha_list)

watcha_list.to_csv('./output/project/왓챠.csv')
# Out:
# C:\Users\na\anaconda3\envs\pydatavenv\lib\site-packages\IPython\core\interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 36: expected 1 fields, saw 2\nSkipping line 52: expected 1 fields, saw 2\nSkipping line 63: expected 1 fields, saw 2\nSkipping line 68: expected 1 fields, saw 2\nSkipping line 122: expected 1 fields, saw 2\nSkipping line 214: expected 1 fields, saw 2\nSkipping line 220: expected 1 fields, saw 2\nSkipping line 276: expected 1 fields, saw 2\n'
#                      왓챠 추천 건텐츠
# 0                       귀멸의 칼날
# 1                귀멸의 칼날: 무한열차편
# 2            극장판 귀멸의 칼날: 무한열차편
# 3                           베놈
# 4                   007 카지노 로얄
# ..                         ...
# 288                   평양까지 이만원
# 289                         박쥐
# 290                      가짜사나이
# 291  Be Loved in House 약정~I Do
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
import time
import re

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.get('https://watcha.com/staffmades/409')

for _ in range(30) :
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(0.5)
print("스크롤완료~~~")

watcha_list=[]
i=1
while True:
    watcha=driver.find_elements_by_css_selector('#root > div.css-4mzu8x-NavManager > main > div.css-4b375e > section > ul > li > div.css-pge0c7-Row > ul > li > div > div.css-1g3awd > div > div')
    for watcha_dom in watcha:
        watcha_list.append(watcha_dom.text)
    time.sleep(0.5)
    print(len(watcha_list))
    i=i+1
    if i==2:
        break
# Out:
# 스크롤완료~~~
# 301

# %%
print(len(watcha_list))
print(watcha_list[0])
print(watcha_list[300])

with open('./output/왓차추천.csv', "wt", encoding="utf-8") as f:
    f.write('왓차_추천\n')
    for i in range(len(watcha_list)):
        f.write('"'+str(watcha_list[i])+'"'+'\n')


with open('./output/왓차2.csv', "wt", encoding="utf-8") as f:
    f.write('왓차추천,왓차추천장르\n')
    for i in range(len(watcha_list)):
        f.write('"'+str(watcha_list[i])+'"'+","+genreList[i]+'\n')
# Out:
# 301
# 귀멸의 칼날
# 씰팀 시즌 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17980/1325226709.py in <module>
#      12     f.write('왓차추천,왓차추천장르\n')
#      13     for i in range(len(watcha_list)):
# ---> 14         f.write('"'+str(watcha_list[i])+'"'+","+genreList[i]+'\n')
#
# IndexError: list index out of range

# %%
import pandas as pd

watcha = pd.read_csv('./output/왓차1.csv',error_bad_lines=False)
display(watcha)
# Out:
# C:\Users\na\anaconda3\envs\pydatavenv\lib\site-packages\IPython\core\interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                           왓차추천 왓차추천장르
# 0                       귀멸의 칼날  애니메이션
# 1                귀멸의 칼날: 무한열차편  애니메이션
# 2            극장판 귀멸의 칼날: 무한열차편  애니메이션
# 3                           베놈     액션
# 4                   007 카지노 로얄     액션
# ..                         ...    ...
# 296                   평양까지 이만원    드라마
# 297                         박쥐    로맨스
# 298                      가짜사나이     예능
# 299  Be Loved in House 약정~I Do    로맨스
# 300                    씰팀 시즌 1     액션
#
# [301 rows x 2 columns]

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
from bs4 import BeautifulSoup
import time
import re

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(3)
driver.get("https://www.netflix.com/")
